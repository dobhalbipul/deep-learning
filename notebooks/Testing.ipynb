# %%
import sys
print("Python version:", sys.version)

import tensorflow as tf
print("TensorFlow version:", tf.__version__)

# print("Num GPUs Available:", len(tf.config.list_physical_devices('GPU'))),
# print("Using GPU:", tf.test.is_gpu_available())
# Out:
# Python version: 3.10.11 (tags/v3.10.11:7d4cc5a, Apr  5 2023, 00:38:17) [MSC v.1929 64 bit (AMD64)]
# TensorFlow version: 2.18.0
# Num GPUs Available: 0
# WARNING:tensorflow:From C:\Users\bdobhalx\AppData\Local\Temp\ipykernel_19256\1759003485.py:8: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# Using GPU: False

# %%
from tensorflow import keras
print("Keras version:", keras.__version__)
# Out:
# Keras version: 3.8.0
