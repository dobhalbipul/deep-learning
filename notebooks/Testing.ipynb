# %%
import sys
print("Python version:", sys.version)

import tensorflow as tf
print("TensorFlow version:", tf.__version__)

# print("Num GPUs Available:", len(tf.config.list_physical_devices('GPU')))
# print("Using GPU:", tf.test.is_gpu_available())
# Out:
# TensorFlow version: 2.18.1

# %%
from tensorflow import keras
print("Keras version:", keras.__version__)
# Out:
# Keras version: 3.10.0

# %%
# check tensorflow_hub version
try:
    import tensorflow_hub as hub
    print("TensorFlow Hub version:", hub.__version__)   
except ImportError:
    print("TensorFlow Hub is not installed.")
# Out:
# c:\Workspace\MyProjects\DeepLearning\venv\lib\site-packages\tensorflow_hub\__init__.py:61: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import parse_version
# WARNING:tensorflow:From c:\Workspace\MyProjects\DeepLearning\venv\lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# TensorFlow Hub version: 0.16.1
